# %%
import pandas as pd

wine_reviews = pd.read_csv("data/447_1.csv")
wine_reviews
# Out:
#                         id       asins                        brand  \
# 0     AV00t6hpvKc47QAVgBMG  B00GFYMHRE                       DUPLIN
# 1     AV00tABdGV-KLJ3ac19r  B06ZZCZD5W             WOODFORD RESERVE
# 2     AV130HZgGV-KLJ3akc7z         NaN                SIERRA NEVADA
# 3     AV130HZgGV-KLJ3akc7z         NaN                SIERRA NEVADA
# 4     AV13Cf3hglJLPUi8O7al         NaN  Cook's California Champagne
# ...                    ...         ...                          ...
# 1226  AWBL6btEKZqtpbFMVyNa         NaN         Vintage Wine Estates
# 1227  AWBL9GJKHh53nbDRCSET         NaN         Vintage Wine Estates
# 1228  AWBL9GJKHh53nbDRCSET         NaN         Vintage Wine Estates
# 1229  AWBL9GJKHh53nbDRCSET         NaN         Vintage Wine Estates
# 1230  AWBL9GJKHh53nbDRCSET         NaN         Vintage Wine Estates
#
#                                              categories             dateAdded  \
# ...
